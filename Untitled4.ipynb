# %%
import tensorflow

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
#kwsmhfiidi = kanchi will send me her face if i do it
kwsmhfiidi= [
    {'ml_education_ner': [{'EducationDegree': [],
    'EducationSubject': [{'name': 'HNC',
      'dna_standard': 'HNC',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor’s',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'High School Diploma',
      'dna_standard': 'High School Diploma (HSD)',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Graduate',
      'dna_standard': 'Graduate',
      'spx_standard': None},
     {'name': 'Law', 'dna_standard': 'Law', 'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'BA',
      'dna_standard': 'Bachelor of Arts (BA)',
      'spx_standard': None},
     {'name': 'BS',
      'dna_standard': 'Bachelor of Science (BS)',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [],
    'EducationSubject': [{'name': 'Advertising',
      'dna_standard': 'Advertising',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'high school degree',
      'dna_standard': 'High School Degree',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [],
    'EducationSubject': [{'name': 'Advertising',
      'dna_standard': 'Advertising',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'High school diploma',
      'dna_standard': 'High School Diploma (HSD)',
      'spx_standard': None},
     {'name': 'general education degree or',
      'dna_standard': 'general education degree or',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor’s',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [{'name': 'Computer Engineering',
      'dna_standard': 'Computer Engineering',
      'spx_standard': None},
     {'name': 'Computer Engineering',
      'dna_standard': 'Computer Engineering',
      'spx_standard': None},
     {'name': 'Software Engineering',
      'dna_standard': 'Software Engineering',
      'spx_standard': None},
     {'name': 'Information Systems',
      'dna_standard': 'Information Systems',
      'spx_standard': None},
     {'name': 'Decision Sciences',
      'dna_standard': 'Decision Sciences',
      'spx_standard': None},
     {'name': 'Data Analytics',
      'dna_standard': 'Data Analytics',
      'spx_standard': None},
     {'name': 'Business Administration',
      'dna_standard': 'Business Administration',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'BA',
      'dna_standard': 'Bachelor of Arts (BA)',
      'spx_standard': None},
     {'name': 'BS',
      'dna_standard': 'Bachelor of Science (BS)',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': []},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'High school',
      'dna_standard': 'High School',
      'spx_standard': None},
     {'name': 'Bachelor’s',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None}],
    'EducationSubject': [{'name': 'SSC',
      'dna_standard': 'SSC',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'PhD',
      'dna_standard': 'Doctor of Philosophy (PhD)',
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []},
   {'EducationDegree': [{'name': "Master's",
      'dna_standard': "Master's Degree",
      'spx_standard': None}],
    'EducationSubject': [],
    'EducationUniversity': [],
    'DegreeProvider': []},
   {'EducationDegree': [],
    'EducationSubject': [{'name': 'life sciences',
      'dna_standard': 'Life Sciences',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []},
   {'EducationDegree': [],
    'EducationSubject': [{'name': 'Science',
      'dna_standard': 'Science',
      'spx_standard': None},
     {'name': 'Chemistry', 'dna_standard': 'Chemistry', 'spx_standard': None},
     {'name': 'Biochemistry',
      'dna_standard': 'Biochemistry',
      'spx_standard': None},
     {'name': 'Biology', 'dna_standard': 'Biology', 'spx_standard': None},
     {'name': 'physical science',
      'dna_standard': 'Physical Science',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]},
 {'ml_education_ner': [{'EducationDegree': [{'name': 'Bachelor’s',
      'dna_standard': "Bachelor's Degree",
      'spx_standard': None},
     {'name': 'Masters',
      'dna_standard': "Master's Degree",
      'spx_standard': None},
     {'name': 'PhD',
      'dna_standard': 'Doctor of Philosophy (PhD)',
      'spx_standard': None}],
    'EducationSubject': [{'name': 'Electrical Engineering',
      'dna_standard': 'Electrical Engineering',
      'spx_standard': None}],
    'EducationUniversity': [],
    'DegreeProvider': []}]}]

# %%
#kwsmhfiidi = kanchi will send me her face if i do it
for item in kwsmhfiidi:
    #print(item.get("ml_education_ner"))
    if len(item)>0:
        y=item.get("ml_education_ner")
        if len(y)>0:
            z=y[0]
            k = z.get("EducationDegree")
            if len(k)>0:
                #print(k[0])
                print(k[0].get("name"))
# Out:
# Bachelor’s
# High School Diploma
# Graduate
# BA
# high school degree
# High school diploma
# Bachelor
# Bachelor
# Bachelor
# Bachelor’s
# BA
# High school
# PhD
# Bachelor’s

# %%
x={'EducationDegree': [], 'EducationSubject': [{'name': 'HNC', 'dna_standard': 'HNC', 'spx_standard': None}], 'EducationUniversity': [], 'DegreeProvider': []}
